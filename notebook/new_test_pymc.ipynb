# %%
import os
os.chdir('/rds/general/user/ma11115/home/pl_temp_fit/')

# %%
import importlib
#importlib.reload(PLPYMCModel)
# %run src/pl_temp_fit/test_EL_fit.py --test_number 5
# Out:
# Running on PyMC v5.10.3
# Running test number 5
# {'num_samples': 40000, 'num_tune': 20000, 'sigma': 0.01, 'temperature_list': array([300., 250., 200., 150.,  80.]), 'number_free_parameters': 3, 'Temp_std_err': 0.1, 'hws_std_err': 0.001, 'relative_intensity_std_error': 0.01}
# 24
# {'number_free_parameters': 3, 'E': {'min': 1.0, 'max': 1.4}, 'k_EXCT': {'min': 8, 'max': 12}, 'fosc_CT': {'min': -4, 'max': 0}, 'LI': {'mu': 0.12, 'sigma': 0.01, 'lower': 0.05, 'upper': 0.15}, 'L0': {'mu': 0.12, 'sigma': 0.01, 'lower': 0.05, 'upper': 0.15}, 'H0': {'mu': 0.12, 'sigma': 0.01, 'lower': 0.12, 'upper': 0.18}, 'Temp_std_err': 0.1, 'hws_std_err': 0.001, 'relative_intensity_std_error': 0.01, 'sigma': 0.01}
# {'draws': 10, 'tune': 5, 'chains': 3, 'step': 'pm.DEMetropolis()', 'return_inferencedata': True}
# {'draws': 40000, 'tune': 20000, 'chains': 4, 'return_inferencedata': True, 'progressbar': True, 'random_seed': None}
# Population sampling (4 chains)
# DEMetropolis: [E, k_EXCT, fosc_CT]
# Attempting to parallelize chains to all cores. You can turn this off with `pm.sample(cores=1)`.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4/4 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='7' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.01% [7/60000 00:03&lt;8:50:09]
#     </div>
# /rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/step_methods/metropolis.py:844: RuntimeWarning: overflow encountered in exp
#   "accept": np.exp(accept),
# /rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/step_methods/metropolis.py:844: RuntimeWarning: overflow encountered in exp
#   "accept": np.exp(accept),
# /rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/step_methods/metropolis.py:844: RuntimeWarning: overflow encountered in exp
#   "accept": np.exp(accept),
# /rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/step_methods/metropolis.py:844: RuntimeWarning: overflow encountered in exp
#   "accept": np.exp(accept),
# Process ChainWalker0:
# Traceback (most recent call last):
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/sampling/population.py", line 262, in _run_secondary
#     update = stepper.step(population[c])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/step_methods/arraystep.py", line 100, in step
#     apoint, stats = self.astep(q)
#                     ^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/step_methods/metropolis.py", line 834, in astep
#     accept = self.delta_logp(q, q0d)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pytensor/compile/function/types.py", line 970, in __call__
#     self.vm()
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pytensor/graph/op.py", line 518, in rval
#     r = p(n, [x[0] for x in i], o)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/pl_temp_fit/src/pl_temp_fit/ELPYMCModel.py", line 56, in perform
#     logl = self.likelihood(
#            ^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/pl_temp_fit/src/pl_temp_fit/ELPYMCModel.py", line 147, in el_loglike
#     model_data = el_trial(list(theta), temperature_list, hws)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/pl_temp_fit/src/pl_temp_fit/ELPYMCModel.py", line 100, in el_trial
#     LTL.LTLCalc(data)
#   File "/rds/general/user/ma11115/home/pl_temp_fit/src/pl_temp_fit/LTL.py", line 16, in LTLCalc
#     data.CT = krad(data.CT, data.c, data.D, data.xParam)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/pl_temp_fit/src/pl_temp_fit/Recombination_Rates.py", line 11, in krad
#     FCWD = FCWD_v(State, C, data.hw, data.T)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/pl_temp_fit/src/pl_temp_fit/Util_functions.py", line 19, in FCWD_v
#     temp, hw_mat, dg0_mat, final_mat, initial_mat = np.meshgrid(T, hw, State.DG0, w_array, t_array)
#                                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/lib/function_base.py", line 5163, in meshgrid
#     output = [x.copy() for x in output]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/rds/general/user/ma11115/home/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/lib/function_base.py", line 5163, in <listcomp>
#     output = [x.copy() for x in output]
#               ^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/pl_temp_fit/src/pl_temp_fit/test_EL_fit.py:183
#     181 print(len(parameter_list))
#     182 #parameter_list[test_number]["test_number"] = test_number
# --> 183 main(**parameter_list[test_number])  # run the example
#
# File ~/pl_temp_fit/src/pl_temp_fit/test_EL_fit.py:52, in main(num_samples, num_tune, sigma, temperature_list, number_free_parameters, hws, Temp_std_err, hws_std_err, relative_intensity_std_error)
#      50 model.sampler_config['step'] = "pm.DEMetropolis()"#"[pm.DEMetropolis([self.E,self.LI,self.sigma_E]),pm.DEMetropolis([self.L0,self.H0])]"
#      51 print(model.sampler_config)
# ---> 52 model.fit(X, truemodel_pl, draws=num_samples, tune=num_tune, chains=4, step=model.sampler_config['step'] , return_inferencedata=True)
#      53 print(az.summary(model.idata))
#      54 model.plot_trace(true_parameters, save_folder=save_folder, savefig=True)
#
# File ~/pl_temp_fit/src/pl_temp_fit/ELPYMCModel.py:335, in ELPYMCModel.fit(self, X, y, progressbar, predictor_names, random_seed, **kwargs)
#     333 sampler_config["random_seed"] = random_seed
#     334 sampler_config.update(**kwargs)
# --> 335 self.idata = self.sample_model(**sampler_config)
#     338 return self.idata
#
# File ~/pl_temp_fit/src/pl_temp_fit/ELPYMCModel.py:196, in ELPYMCModel.sample_model(self, **kwargs)
#     194 sampler_args.pop('step')
#     195 print(sampler_args)
# --> 196 idata = pm.sample(step=eval(step),**sampler_args)
#     197 idata.extend(pm.sample_prior_predictive(), join="right")
#     198 idata.extend(pm.sample_posterior_predictive(idata), join="right")
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/sampling/mcmc.py:817, in sample(draws, tune, chains, cores, random_seed, progressbar, step, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, model, **kwargs)
#     815     _log.info(f"Population sampling ({chains} chains)")
#     816     _print_step_hierarchy(step)
# --> 817     _sample_population(initial_points=initial_points, parallelize=cores > 1, **sample_args)
#     818 else:
#     819     _log.info(f"Sequential sampling ({chains} chains in 1 job)")
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/sampling/population.py:106, in _sample_population(initial_points, draws, start, random_seed, step, tune, model, progressbar, parallelize, traces, **kwargs)
#     103 if progressbar:
#     104     sampling = progress_bar(sampling, total=draws, display=progressbar)
# --> 106 for i in sampling:
#     107     pass
#     108 return
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/site-packages/fastprogress/fastprogress.py:41, in ProgressBar.__iter__(self)
#      39 if self.total != 0: self.update(0)
#      40 try:
# ---> 41     for i,o in enumerate(self.gen):
#      42         if self.total and i >= self.total: break
#      43         yield o
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/sampling/population.py:415, in _iter_population(draws, tune, popstep, steppers, traces, points)
#     410 with popstep:
#     411     # iterate draws of all chains
#     412     for i in range(draws):
#     413         # this call steps all chains and returns a list of (point, stats)
#     414         # the `popstep` may interact with subprocesses internally
# --> 415         updates = popstep.step(i == tune, points)
#     417         # apply the update to the points and record to the traces
#     418         for c, strace in enumerate(traces):
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/sampling/population.py:289, in PopulationStepper.step(self, tune_stop, population)
#     287     # Blockingly get the step outcomes
#     288     for c in range(self.nchains):
# --> 289         updates.append(self._primary_ends[c].recv())
#     290 else:
#     291     for c in range(self.nchains):
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/multiprocessing/connection.py:250, in _ConnectionBase.recv(self)
#     248 self._check_closed()
#     249 self._check_readable()
# --> 250 buf = self._recv_bytes()
#     251 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/multiprocessing/connection.py:430, in Connection._recv_bytes(self, maxsize)
#     429 def _recv_bytes(self, maxsize=None):
# --> 430     buf = self._recv(4)
#     431     size, = struct.unpack("!i", buf.getvalue())
#     432     if size == -1:
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/multiprocessing/connection.py:395, in Connection._recv(self, size, read)
#     393 remaining = size
#     394 while remaining > 0:
# --> 395     chunk = read(handle, remaining)
#     396     n = len(chunk)
#     397     if n == 0:
#
# KeyboardInterrupt:

# %%
script="#!/bin/bash \n"+\
    "#PBS -l walltime=17:59:01 \n"+\
    "#PBS -l select=1:ncpus=16:mem=4gb:avx=true \n"+\
    f"#PBS -J 1-{36} \n"+\
    " \n"+\
    "cd /rds/general/user/ma11115/home/pl_temp_fit/ \n"+\
    "module load anaconda3/personal \n"+ \
    "source activate pymc_env     \n"+\
    f"python src/pl_temp_fit/test_EL_fit.py --test_number ${'PBS_ARRAY_INDEX'} \n"
#print(script) 
with open(f'HPC_bash_script/Runtest.sh', 'wb') as f:
    f.write( bytes(script, 'utf-8'))  

# !qsub  -e ./cache -o ./cache HPC_bash_script/Runtest.sh
# Out:
# /bin/bash: which: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `which'
# /bin/bash: module: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `module'
# /bin/bash: scl: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `scl'
# /bin/bash: ml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `ml'
# /bin/sh: which: line 1: syntax error: unexpected end of file
# /bin/sh: error importing function definition for `which'
# /bin/sh: ml: line 1: syntax error: unexpected end of file
# /bin/sh: error importing function definition for `ml'
# /bin/sh: scl: line 1: syntax error: unexpected end of file
# /bin/sh: error importing function definition for `scl'
# /bin/sh: module: line 1: syntax error: unexpected end of file
# /bin/sh: error importing function definition for `module'
# sh: which: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `which'
# sh: ml: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `ml'
# sh: scl: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `scl'
# sh: module: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `module'
# sh: which: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `which'
# sh: ml: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `ml'
# sh: scl: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `scl'
# sh: module: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `module'
# 8686577[].pbs
