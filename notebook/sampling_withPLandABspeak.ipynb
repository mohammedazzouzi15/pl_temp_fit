# %% [markdown]
# ## Run bayesian inference
#
# the notebook start by first loading the model config and checking the data,
#
# then you can run the sampling either in the HPC or in the notebook

# %%
# load the relevant modules for the analysis

import os
from pathlib import Path

import numpy as np
import pandas as pd
from pl_temp_fit import (
    Exp_data_utils,
    config_utils,
    covariance_utils,
    generate_data_utils,
)

# access the right directory
os.chdir("/media/mohammed/Work/pl_temp_fit")
#os.chdir('C:\\Users\\ma11115\\OneDrive - Imperial College London\\pl_temp_fit')

# %%
# get test_ids in the database
path_database = Path("fit_experimental_emcee_pl/fit_data_base/")
model_config_files = list(path_database.glob("*.json"))
test_id_list = []
list_model_config = []
for id,model_config_file in enumerate(model_config_files):
    #print(id,model_config_file)
    test_id = model_config_file.name.replace(".json","")
    test_id_list.append(test_id)
    model_config,model_config_save = config_utils.load_model_config(test_id, database_folder = path_database)
    #print(model_config_save["csv_name_pl"].split("/")[-1])
    list_model_config.append(model_config_save)

if len(list_model_config) == 0:
    print("no data")
else:
    df_all = pd.DataFrame(list_model_config)
    df_all.sort_values(by="date", ascending=False, inplace=True)
df_all["csv_name_pl"] = df_all["csv_name_pl"].apply(lambda x: x.split("/")[-1])
df_all[["csv_name_pl","params_to_fit_init","min_bounds","max_bounds"]].head(10)
# Out:
#                                           csv_name_pl  \
# 16                    Y6-soln_mod_split0_split500.csv
# 2   Y6DIB-1mat-300K_G0_700.0nm_1500.0nm_21-06-2024...
# 27  Y6_1mat_300_G0_700.0nm_1500.0nm_20-06-2024-16h...
# 7                     Y6-soln_mod_split0_split500.csv
# 25                    Y6-soln_mod_split0_split500.csv
# 1   Y6DIB-1mat-300K_G0_700.0nm_1500.0nm_21-06-2024...
# 29  Y6DIB-1mat-300K_G0_700.0nm_1500.0nm_21-06-2024...
# 24  Y6DIB-1mat-300K_G0_700.0nm_1500.0nm_21-06-2024...
# 15  Y6DIB-1mat-300K_G0_700.0nm_1500.0nm_21-06-2024...
# 31  Y6DIB-1mat-300K_G0_700.0nm_1500.0nm_21-06-2024...
#
#                                    params_to_fit_init  \
# 16  {'EX': {'E': 1.6, 'sigma': 0.01, 'Li': 0.078, ...
# 2   {'EX': {'E': 1.37, 'sigma': 0.01, 'Li': 0.078,...
# 27  {'EX': {'E': 1.37, 'sigma': 0.04, 'Li': 0.078,...
# 7   {'EX': {'E': 1.7, 'sigma': 0.04, 'Li': 0.078, ...
# 25  {'EX': {'E': 1.37, 'sigma': 0.01, 'Li': 0.078,...
# 1   {'EX': {'E': 1.37, 'sigma': 0.01, 'Li': 0.078,...
# 29  {'EX': {'E': 1.37, 'sigma': 0.04, 'Li': 0.078,...
# 24  {'EX': {'E': 1.37, 'sigma': 0.04, 'Li': 0.078,...
# 15  {'EX': {'E': 1.37, 'sigma': 0.01, 'Li': 0.078,...
# 31  {'EX': {'E': 1.37, 'sigma': 0.01, 'Li': 0.078,...
#
#                                            min_bounds  \
# 16  {'EX': {'E': 1.2, 'sigma': 0.001, 'Li': 0.03, ...
# 2   {'EX': {'E': 1.2, 'sigma': 0.001, 'Li': 0.03, ...
# 27  {'EX': {'E': 1.3, 'sigma': 0.001, 'Li': 0.03, ...
# 7   {'EX': {'E': 1.3, 'sigma': 0.001, 'Li': 0.03, ...
# 25  {'EX': {'E': 1.2, 'sigma': 0.001, 'Li': 0.03, ...
# 1   {'EX': {'E': 1.2, 'sigma': 0.001, 'Li': 0.03, ...
# 29  {'EX': {'E': 1.3, 'sigma': 0.001, 'Li': 0.03, ...
# 24  {'EX': {'E': 1.3, 'sigma': 0.001, 'Li': 0.03, ...
# 15  {'EX': {'E': 1.3, 'sigma': 0.001, 'Li': 0.03, ...
# 31  {'EX': {'E': 1.3, 'sigma': 0.001, 'Li': 0.03, ...
#
#                                            max_bounds
# 16  {'EX': {'E': 2.1, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 2   {'EX': {'E': 1.6, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 27  {'EX': {'E': 1.5, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 7   {'EX': {'E': 1.8, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 25  {'EX': {'E': 1.6, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 1   {'EX': {'E': 1.6, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 29  {'EX': {'E': 1.5, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 24  {'EX': {'E': 1.5, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 15  {'EX': {'E': 1.5, 'sigma': 0.03, 'Li': 0.2, 'L...
# 31  {'EX': {'E': 1.5, 'sigma': 0.03, 'Li': 0.2, 'L...

# %%
search_for = "Y6-soln"
df_all[df_all["csv_name_pl"].str.contains(search_for)][["csv_name_pl","params_to_fit_init","min_bounds","max_bounds"]]
# Out:
#                         csv_name_pl  \
# 16  Y6-soln_mod_split0_split500.csv
# 7   Y6-soln_mod_split0_split500.csv
# 25  Y6-soln_mod_split0_split500.csv
#
#                                    params_to_fit_init  \
# 16  {'EX': {'E': 1.6, 'sigma': 0.01, 'Li': 0.078, ...
# 7   {'EX': {'E': 1.7, 'sigma': 0.04, 'Li': 0.078, ...
# 25  {'EX': {'E': 1.37, 'sigma': 0.01, 'Li': 0.078,...
#
#                                            min_bounds  \
# 16  {'EX': {'E': 1.2, 'sigma': 0.001, 'Li': 0.03, ...
# 7   {'EX': {'E': 1.3, 'sigma': 0.001, 'Li': 0.03, ...
# 25  {'EX': {'E': 1.2, 'sigma': 0.001, 'Li': 0.03, ...
#
#                                            max_bounds
# 16  {'EX': {'E': 2.1, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 7   {'EX': {'E': 1.8, 'sigma': 0.1, 'Li': 0.2, 'Lo...
# 25  {'EX': {'E': 1.6, 'sigma': 0.1, 'Li': 0.2, 'Lo...

# %%
import importlib
# load and update the model config
importlib.reload(config_utils)
test_id = test_id_list[16]
model_config,model_config_save = config_utils.load_model_config(test_id, database_folder = path_database)
csv_name = model_config_save["csv_name_pl"]
print(model_config_save["csv_name_pl"].split("/")[-1])
# add the new experimental data
model_config_save["params_to_fit_init"] = {
    "EX": {"E": 1.6, "sigma": 0.01, "Li": 7.8e-2, "Lo": 0.11, "hO": 0.159, "disorder_ext": 0.05},
    "CT": {},
    "D": {},
}
model_config_save["min_bounds"] = {
    "EX": {"E": 1.2, "sigma": 0.001, "Li": 0.03, "Lo": 0.03, "hO": 0.1, "disorder_ext": 0.01},
    "CT": {},
    "D": {},
}
model_config_save["max_bounds"] = {
    "EX": {"E": 2.1, "sigma": 0.1, "Li": 0.2, "Lo": 0.2, "hO": 0.2, "disorder_ext": 0.1},
    "CT": {},
    "D": {},
}

model_config_save["max_abs_pos_exp"] = 1.95
model_config_save["error_in_max_abs_pos"] = 0.01 # in eV

config_utils.updata_model_config(test_id,path_database, model_config_save)
# Out:
# Y6-soln_mod_split0_split500.csv
# '38f591be-e7e8-400f-97b5-b9024d928a17'

# %%
# plot the results with initial parameters
# and the maximum and minumum bounds
import importlib

from pl_temp_fit import fit_pl_utils

importlib.reload(fit_pl_utils)

fit_pl_utils.plot_fit_limits(model_config,model_config_save)
# Out:
# shape of mean value plot is (50, 7)

# %% [markdown]
# ### run sampler in the notebook

# %%
import emcee

filename = model_config_save["save_folder"] + "/sampler.h5"
if os.path.exists(filename):
    try:
        reader = emcee.backends.HDFBackend(filename, name="multi_core")
        distribution = reader.get_chain(discard=0, flat=True)  
        true_parameters = fit_pl_utils.get_param_dict(model_config_save["params_to_fit_init"],distribution[-1])
    except AttributeError:
        print("no sampler found")
        true_parameters = model_config_save["params_to_fit_init"]
else:
    true_parameters = model_config_save["params_to_fit_init"]
    print("no sampler found")

# %%
from pl_temp_fit.data_generators import PLAbs

importlib.reload(PLAbs)
save_folder = model_config_save["save_folder"]
csv_name = model_config_save["csv_name_pl"]

Exp_data, temperature_list, hws = Exp_data_utils.read_data(csv_name)

pl_data_gen = PLAbs.PLAbs(temperature_list,hws)
pl_data_gen.error_in_max_abs_pos = model_config_save["error_in_max_abs_pos"]
pl_data_gen.max_abs_pos_exp = model_config_save["max_abs_pos_exp"]

pl_data_gen.update_with_model_config(model_config_save)
co_var_mat_pl, variance_pl = pl_data_gen.get_covariance_matrix()

# %%
#test log likelihood
from pl_temp_fit import Emcee_utils, fit_pl_utils, FitUtils

save_folder = model_config_save["save_folder"]

inv_cov_pl = np.linalg.inv(co_var_mat_pl)
coords, _ = FitUtils.get_initial_coords(
        pl_data_gen,
        coeff_spread=0.1,
        num_coords=32,
        save_folder=save_folder,
        restart_sampling=False,  
    )
log_like, chi_squared, data = pl_data_gen.log_likelihood(
            coords[0],
            Exp_data,
            inv_cov_pl,
        )
data.D.hw[data.D.alpha[:, -1].argmax()]
# Out:
# np.float64(1.8900000000000001)

# %%
from pl_temp_fit import Emcee_utils, fit_pl_utils, FitUtils
importlib.reload(generate_data_utils)
importlib.reload(covariance_utils)
importlib.reload(FitUtils)
importlib.reload(fit_pl_utils)

save_folder = model_config_save["save_folder"]

fit_pl_utils.run_sampler_parallel(
    save_folder,
    Exp_data,
    co_var_mat_pl,
    pl_data_gen,
    nsteps=5000,
    coeff_spread=0.1,
    num_coords = 32,
    restart_sampling=False,
    num_processes=30,
)
# Out:
#   0%|          | 8/5000 [00:16<2:49:41,  2.04s/it]

# %%
from pl_temp_fit import Emcee_utils, fit_pl_utils

importlib.reload(generate_data_utils)
importlib.reload(covariance_utils)
importlib.reload(fit_pl_utils)
importlib.reload(Emcee_utils)

filename = model_config_save["save_folder"] + "/sampler_single.h5"
if os.path.exists(filename):
    reader = emcee.backends.HDFBackend(filename, name="multi_core")
    distribution = reader.get_chain(discard=0, flat=True)  
    true_parameters = fit_pl_utils.get_param_dict(model_config_save["params_to_fit_init"],distribution[-1])
else:
    true_parameters = model_config_save["params_to_fit_init"]
    print("no sampler found")
save_folder = model_config_save["save_folder"] + "/single_core"
os.makedirs(save_folder, exist_ok=True)
fit_pl_utils.run_sampler_single(
    save_folder,
    Exp_data,
    co_var_mat_pl,
    pl_data_gen,
    nsteps=5,
    coeff_spread=0.1,
    num_coords = 32,
    restart_sampling=False,
)
# Out:
# no sampler found
# emcee: Exception while calling your likelihood function:
#   params: [1.59730195 0.01037421 0.07950407 0.11260293 0.15851658 0.05083488]
#   args: []
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
#   File "/media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/fit_pl_utils.py", line 127, in log_probability_glob
#     return data_generator.log_probability(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/data_generators/PLAbs.py", line 24, in log_probability
#     log_like, chi_squared, data = self.log_likelihood(
#                                   ^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/data_generators/SpectralDataGeneration.py", line 144, in log_likelihood
#     model_data, data_model = self.generate_data(params_to_fit_updated)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/data_generators/SpectralDataGeneration.py", line 106, in generate_data
#     LTL.ltlcalc(data)
#   File "/media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/model_function/LTL.py", line 34, in ltlcalc
#     data.EX = krad(data.EX, data.c, data.D, data.xParam)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/model_function/RecombinationRates.py", line 11, in krad
#     FCWD = FCWD_v(State, C, data.hw, data.T)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/model_function/UtilFunctions.py", line 39, in FCWD_v
#     component2 = np.exp(-hrf) * hrf ** (final_mat - initial_mat) * factorial(initial_mat) / factorial(final_mat)
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/scipy/special/_basic.py", line 3060, in factorial
#     return _factorialx_array_approx(n, k=1)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/scipy/special/_basic.py", line 2933, in _factorialx_array_approx
#     n_to_compute = extract(cond, n)
#                    ^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py", line 1982, in extract
#     return _nx.take(ravel(arr), nonzero(ravel(condition))[0])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/numpy/_core/fromnumeric.py", line 207, in take
#     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 18
#      16 save_folder = model_config_save["save_folder"] + "/single_core"
#      17 os.makedirs(save_folder, exist_ok=True)
# ---> 18 fit_pl_utils.run_sampler_single(
#      19     save_folder,
#      20     Exp_data,
#      21     co_var_mat_pl,
#      22     pl_data_gen,
#      23     nsteps=5,
#      24     coeff_spread=0.1,
#      25     num_coords = 32,
#      26     restart_sampling=False,
#      27 )
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/fit_pl_utils.py:133, in run_sampler_single(save_folder, Exp_data_pl, co_var_mat_pl, data_generator, nsteps, coeff_spread, num_coords, restart_sampling)
#     126 def log_probability_glob(theta):
#     127     return data_generator.log_probability(
#     128         theta,
#     129         Exp_data_pl,
#     130         inv_cov_pl,
#     131     )
# --> 133 return FitUtils.run_single_process_sampling(
#     134     log_probability_glob,
#     135     coords,
#     136     backend,
#     137     dtype=dtype,
#     138     nsteps=nsteps,
#     139 )
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/FitUtils.py:144, in run_single_process_sampling(log_probability_glob, coords, backend, dtype, nsteps)
#     142 old_tau = np.inf
#     143 # Now we'll sample for up to max_n steps
# --> 144 for _ in sampler.sample(
#     145     coords, iterations=nsteps, progress=True, blobs0=[]
#     146 ):
#     147     # Only check convergence every 100 steps
#     148     if sampler.iteration % 100:
#     149         continue
#
# File /media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/emcee/ensemble.py:344, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     342     state.blobs = blobs0
#     343 if state.log_prob is None:
# --> 344     state.log_prob, state.blobs = self.compute_log_prob(state.coords)
#     345 if np.shape(state.log_prob) != (self.nwalkers,):
#     346     raise ValueError("incompatible input dimensions")
#
# File /media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/emcee/ensemble.py:489, in EnsembleSampler.compute_log_prob(self, coords)
#     487     else:
#     488         map_func = map
# --> 489     results = list(map_func(self.log_prob_fn, p))
#     491 try:
#     492     log_prob = np.array([float(l[0]) for l in results])
#
# File /media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/emcee/ensemble.py:624, in _FunctionWrapper.__call__(self, x)
#     622 def __call__(self, x):
#     623     try:
# --> 624         return self.f(x, *self.args, **self.kwargs)
#     625     except:  # pragma: no cover
#     626         import traceback
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/fit_pl_utils.py:127, in run_sampler_single.<locals>.log_probability_glob(theta)
#     126 def log_probability_glob(theta):
# --> 127     return data_generator.log_probability(
#     128         theta,
#     129         Exp_data_pl,
#     130         inv_cov_pl,
#     131     )
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/data_generators/PLAbs.py:24, in PLAbs.log_probability(self, theta, exp_data, inv_co_var_mat_pl)
#      22 if lp == -np.inf:
#      23     return -np.inf, None, None, None, None, None # do not forget to return the correct number of outputs
# ---> 24 log_like, chi_squared, data = self.log_likelihood(
#      25     theta,
#      26     exp_data,
#      27     inv_co_var_mat_pl,
#      28 )
#      29 log_prob = lp + log_like[0][0]
#      30 log_prob += -(data.D.hw[data.D.alpha[:, -1].argmax()]   - self.max_abs_pos_exp)**2 / self.error_in_max_abs_pos**2/2
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/data_generators/SpectralDataGeneration.py:144, in SpectralDataGeneration.log_likelihood(self, theta, exp_data, inv_co_var_mat_pl)
#     126 """Calculate the log likelihood and the chi squared of the model data and the experimental data.
#     127
#     128 Args:
#    (...)
#     141
#     142 """
#     143 params_to_fit_updated = self.update_params_to_fit(theta)
# --> 144 model_data, data_model = self.generate_data(params_to_fit_updated)
#     145 model_data = model_data / np.max(model_data.reshape(-1, 1))
#     146 exp_data = exp_data / np.max(exp_data.reshape(-1, 1))
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/data_generators/SpectralDataGeneration.py:106, in SpectralDataGeneration.generate_data(self, params_to_fit)
#     102 hws_list = self.hws_list + np.random.normal(
#     103     0, self.error_hws_sigma, len(self.hws_list)
#     104 )
#     105 data.D.T = temperature_list
# --> 106 LTL.ltlcalc(data)
#     107 model_data = data.D.kr_hw
#     108 model_data_interp = np.zeros(
#     109     (len(self.hws_list), len(self.temperature_list))
#     110 )
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/model_function/LTL.py:34, in ltlcalc(data)
#      21 def ltlcalc(data):
#      22     """Calculate the low temperature luminescence spectra of organic semiconductors.
#      23
#      24     Args:
#    (...)
#      32
#      33     """
# ---> 34     data.EX = krad(data.EX, data.c, data.D, data.xParam)
#      35     data.EX = knonrad(data.EX, data.c, data.D, data.xParam)
#      36     data.EX = kabs(data.EX, data.c, data.D, data.xParam)
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/model_function/RecombinationRates.py:11, in krad(State, C, data, xParam)
#       9 def krad(State, C, data, xParam):
#      10     dE = State.DG0[1] - State.DG0[0]
# ---> 11     FCWD = FCWD_v(State, C, data.hw, data.T)
#      12     M = tdm(State, C)
#      13     Zrec = Z_rec(State, C, data, xParam)
#
# File /media/mohammed/Work/pl_temp_fit/src/pl_temp_fit/model_function/UtilFunctions.py:39, in FCWD_v(State, const, hw, T)
#      37 # Calculate each component of the FCWD_n expression
#      38 component1 = 1 / np.sqrt(4 * np.pi * State.Lo * const.kb * temp)
# ---> 39 component2 = np.exp(-hrf) * hrf ** (final_mat - initial_mat) * factorial(initial_mat) / factorial(final_mat)
#      40 component3 = lagur**2
#      41 component4 = np.exp(
#      42     -((hw_mat - dg0_mat + State.Lo + (final_mat - initial_mat) * State.hO) ** 2)
#      43     / (4 * State.Lo * const.kb * temp)
#      44 )
#
# File /media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/scipy/special/_basic.py:3060, in factorial(n, exact)
#    3058 if exact:
#    3059     return _factorialx_array_exact(n, k=1)
# -> 3060 return _factorialx_array_approx(n, k=1)
#
# File /media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/scipy/special/_basic.py:2933, in _factorialx_array_approx(n, k)
#    2931 # only compute where n >= 0 (excludes nans), everything else is 0
#    2932 cond = (n >= 0)
# -> 2933 n_to_compute = extract(cond, n)
#    2934 place(result, cond, _factorialx_approx_core(n_to_compute, k=k))
#    2935 return result
#
# File /media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:1982, in extract(condition, arr)
#    1932 @array_function_dispatch(_extract_dispatcher)
#    1933 def extract(condition, arr):
#    1934     """
#    1935     Return the elements of an array that satisfy some condition.
#    1936
#    (...)
#    1980
#    1981     """
# -> 1982     return _nx.take(ravel(arr), nonzero(ravel(condition))[0])
#
# File /media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:207, in take(a, indices, axis, out, mode)
#     109 @array_function_dispatch(_take_dispatcher)
#     110 def take(a, indices, axis=None, out=None, mode='raise'):
#     111     """
#     112     Take elements from an array along an axis.
#     113
#    (...)
#     205            [5, 7]])
#     206     """
# --> 207     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#
# File /media/mohammed/Work/anaconda3/envs/pl_temp_fit/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
soln_min = pl_data_gen.get_maximum_likelihood_estimate(
        Exp_data,
        co_var_mat_pl,
        save_folder,
        coeff_spread=0.1,
        num_coords=5,
    )

# %% [markdown]
# ### run sampling in the HPC

# %%
model_config_id = test_id
csv_name = model_config_save["csv_name_pl"]
results_name = csv_name.replace(".csv","").split("/")[-1]
sh_name = f"Run_EMCEE_{results_name}.sh"
script="#!/bin/bash \n"+\
    "#PBS -l walltime=07:59:01 \n"+\
    "#PBS -l select=1:ncpus=32:mem=80gb:avx=true \n"+\
    " \n"+\
    "cd /rds/general/user/ma11115/home/pl_temp_fit/ \n"+\
    "module load anaconda3/personal \n"+ \
    "source activate pl_temp_fit     \n"+\
    f"python src/pl_temp_fit/scripts/new_pl_sampling_abs.py --model_config_id {model_config_id} \n"#${'PBS_ARRAY_INDEX'}#f"#PBS -J 1-{16} \n"+\
print(script) 
path_to_script = f'HPC_bash_script'
Path(path_to_script).mkdir(parents=True, exist_ok=True)

with Path(path_to_script,f'{sh_name}').open('wb') as f:
    f.write( bytes(script, 'utf-8'))  
script= f"qsub  -e ./cache -o ./cache HPC_bash_script/{sh_name}"#submit to HPC
#os.system(script)
# Out:
# #!/bin/bash
# #PBS -l walltime=07:59:01
# #PBS -l select=1:ncpus=32:mem=80gb:avx=true
#
# cd /rds/general/user/ma11115/home/pl_temp_fit/
# module load anaconda3/personal
# source activate pl_temp_fit
# python src/pl_temp_fit/scripts/new_pl_sampling_abs.py --model_config_id 38f591be-e7e8-400f-97b5-b9024d928a17

# %% [markdown]
# to run the scipt using the hpc you can just submit the job above
#
# if you want ot run the job on the terminal you can run the script from the folder of pl_temp_fit using  for example
#
#         python src/pl_temp_fit/scripts/run_pl_sampling.py --model_config_id e7ed53f3-f1ef-46c2-9b98-35b366e9f04d
#
# where e7ed53f3-f1ef-46c2-9b98-35b366e9f04d  correspond to your model config id
